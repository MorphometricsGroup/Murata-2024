# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pathlib
import os

# %%
def parapara(num):
    # インスペクターから得た位置とオイラー角を読み込む
    folder_path = pathlib.Path("cam_pos_rot")
    file_path = os.path.join(folder_path, str(num)+".csv")
    pos_rot = np.loadtxt(file_path,delimiter=",")
    t = pos_rot[0,:]*10
    angles = pos_rot[1,:]
    angles = np.array([angles[0],angles[1],angles[2]])
    return t, angles

# %%
def rotation(R_mat, t_vec):
    world_loc = np.array([0, 0, 0])
    world_ax = np.array([[1, 0, 0],
                          [0, 1, 0],
                          [0, 0, -1]])
    
    loc = world_loc + t_vec
    ax_mat = np.dot(R_mat, world_ax)
    x_vec, y_vec, z_vec = ax_mat[0,0:3], ax_mat[1,0:3], ax_mat[2,0:3]
    
    return loc, x_vec, y_vec, z_vec

# %%
def roted_ax(loc, x_vec, y_vec, z_vec):

    # x軸
    #ax.quiver(loc[0], loc[1], loc[2],
    #            x_vec[0], x_vec[1], x_vec[2],
    #            color = "red", length = 1, arrow_length_ratio = 0.2)

    # y軸
    #ax.quiver(loc[0], loc[1], loc[2],
    #            y_vec[0], y_vec[1], y_vec[2],
    #            color = "green", length = 1, arrow_length_ratio = 0.2)
    # z軸
    ax.quiver(loc[0], loc[1], loc[2],
                z_vec[0], z_vec[1], z_vec[2],
                color = "blue", length = 10, arrow_length_ratio = 0.2)

# %%
# x-y平面に向かう(z軸:-1)
def Rx(angle):
    angle = angle - 90
    return np.array([[1, 0, 0],
                    [0, np.cos(np.radians(angle)), np.sin(np.radians(angle))],
                    [0, -np.sin(np.radians(angle)), np.cos(np.radians(angle))]])

def Ry(angle):
    #angle = 360 - angle
    return np.array([[np.cos(np.radians(angle)), 0, -np.sin(np.radians(angle))],
                    [0, 1, 0],
                    [np.sin(np.radians(angle)), 0, np.cos(np.radians(angle))]])

def Rz(angle):
    angle = 360 - angle
    return np.array([[np.cos(np.radians(angle)), np.sin(np.radians(angle)), 0],
                    [-np.sin(np.radians(angle)), np.cos(np.radians(angle)), 0],
                    [0, 0, 1]])

def R_mat(angles):
    return np.dot(Rx(angles[0]),Rz(angles[2]))

# %%
# z-x平面に向かう(z軸:-1)
def Rx(angle):
    angle = 360 - angle +180
    return np.array([[1, 0, 0],
                    [0, np.cos(np.radians(angle)), np.sin(np.radians(angle))],
                    [0, -np.sin(np.radians(angle)), np.cos(np.radians(angle))]])

def Ry(angle):
    angle = 360 - angle
    return np.array([[np.cos(np.radians(angle)), 0, -np.sin(np.radians(angle))],
                    [0, 1, 0],
                    [np.sin(np.radians(angle)), 0, np.cos(np.radians(angle))]])

def Rz(angle):
    angle = 360 - angle
    return np.array([[np.cos(np.radians(angle)), np.sin(np.radians(angle)), 0],
                    [-np.sin(np.radians(angle)), np.cos(np.radians(angle)), 0],
                    [0, 0, 1]])

def R_mat(angles):
    return np.dot(Rx(angles[0]),Ry(angles[1]))

# %%
# x-y平面に向かう(z軸:1)
def Rx(angle):
    angle = 360 - angle - 90
    return np.array([[1, 0, 0],
                    [0, np.cos(np.radians(angle)), np.sin(np.radians(angle))],
                    [0, -np.sin(np.radians(angle)), np.cos(np.radians(angle))]])

def Ry(angle):
    #angle = 360 - angle
    return np.array([[np.cos(np.radians(angle)), 0, -np.sin(np.radians(angle))],
                    [0, 1, 0],
                    [np.sin(np.radians(angle)), 0, np.cos(np.radians(angle))]])

def Rz(angle):
    angle = 360 - angle
    return np.array([[np.cos(np.radians(angle)), np.sin(np.radians(angle)), 0],
                    [-np.sin(np.radians(angle)), np.cos(np.radians(angle)), 0],
                    [0, 0, 1]])

def R_mat(angles):
    return np.dot(Rx(angles[0]),Rz(angles[2]))

# %%
# z-x平面に向かう(z軸:1)
def Rx(angle):
    angle = angle
    return np.array([[1, 0, 0],
                    [0, np.cos(np.radians(angle)), np.sin(np.radians(angle))],
                    [0, -np.sin(np.radians(angle)), np.cos(np.radians(angle))]])

def Ry(angle):
    angle = 180-angle
    return np.array([[np.cos(np.radians(angle)), 0, -np.sin(np.radians(angle))],
                    [0, 1, 0],
                    [np.sin(np.radians(angle)), 0, np.cos(np.radians(angle))]])

def Rz(angle):
    #angle = 360 - angle
    return np.array([[np.cos(np.radians(angle)), np.sin(np.radians(angle)), 0],
                    [-np.sin(np.radians(angle)), np.cos(np.radians(angle)), 0],
                    [0, 0, 1]])

def R_mat(angles):
    return np.dot(Rx(angles[0]),Ry(angles[1]))

# %%
fig = plt.figure(figsize = (10, 8))
ax = fig.add_subplot(111, projection='3d')
    # 軸ラベルの設定
ax.set_xlabel("x", fontsize = 16)
ax.set_ylabel("y", fontsize = 16)
ax.set_zlabel("z", fontsize = 16)

# 軸範囲の設定
ax.set_xlim(-30, 30)
ax.set_ylim(-30, 30)
ax.set_zlim(-30, 30)

# 格子点の作成
x = np.arange(-30, 30, 2)
y = np.arange(-30, 30, 2)
xx, yy = np.meshgrid(x, y)



for i in range(25):
    t, angles = parapara(i)
    #t = np.array([t[2], t[1], t[0]])
    #angles = np.array([angles[0], angles[2], angles[1]])
    R = R_mat(angles)
    loc, x_vec, y_vec, z_vec = rotation(R, t)
    roted_ax(loc, x_vec, y_vec, z_vec)
    tr = -np.dot(np.linalg.pinv(R.T),t)
    ex_para = np.concatenate([R, np.reshape(tr,(3,1))], 1)
    np.savetxt('_view_mat/'+str(i)+'.csv', ex_para, delimiter=',', fmt='%f')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
def para_load(num):
    #インスペクターから得た値で計算した後のパラメータを読み込む
    folder_path = pathlib.Path("view_mat")
    file_path = os.path.join(folder_path, str(num)+".csv")
    Rt = np.loadtxt(file_path, delimiter="\t")
    #R = Rt[0:3, 0:3]
    #t = Rt[0:3, 3]
    return Rt#R, t

# %%
fig = plt.figure(figsize = (10, 8))
ax = fig.add_subplot(111, projection='3d')
    # 軸ラベルの設定
ax.set_xlabel("x", fontsize = 16)
ax.set_ylabel("y", fontsize = 16)
ax.set_zlabel("z", fontsize = 16)

# 軸範囲の設定
ax.set_xlim(-3, 3)
ax.set_ylim(-3, 3)
ax.set_zlim(-3, 3)

# 格子点の作成
x = np.arange(-3, 3, 0.2)
y = np.arange(-3, 3, 0.2)
xx, yy = np.meshgrid(x, y)



for i in range(25):
    
    Rt = para_load(i)
    loc, x_vec, y_vec, z_vec = rotation(R, t)
    roted_ax(loc, x_vec, y_vec, z_vec)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
for i in range(25):
    #print(i)
    Rt = para_load(i)
    #t, angles = parapara(i)
    #print(np.dot(Rt, np.array([t[0],t[1],t[2],1])))
    R = Rt[0:3, 0:3]
    t = Rt[0:3, 3]
    c = np.dot(-R.T, t)
    print(c)
# Out:
# [ 7.49987872 25.99997706 13.00015082]
# [-13.0000295   14.99992404  22.49989019]
# [13.00015082 25.99997706  7.49987872]
# [13.0000295  14.99992404 22.49989019]
# [ 13.00002483  14.99992045 -22.49988211]
# [26.00012346 15.00004894  0.        ]
# [ 0.         15.00004894 26.00012346]
# [  0.          25.99989841 -15.000063  ]
# [22.49989019 14.99992404 13.0000295 ]
# [-22.49988211  14.99992045 -13.00002483]
# [13.00014578 25.99996892 -7.49987582]
# [-13.00015082  25.99997706   7.49987872]
# [-22.49989019  14.99992404  13.0000295 ]
# [-13.00002483  14.99992045 -22.49988211]
# [15.000063   25.99989841  0.        ]
# [  0.          15.00004894 -26.00012346]
# [-13.00014578  25.99996892  -7.49987582]
# [  7.49987582  25.99996892 -13.00014578]
# [-26.00012346  15.00004894   0.        ]
# [-15.000063    25.99989841   0.        ]
# [ -7.49987582  25.99996892 -13.00014578]
# [ 0.         25.99989841 15.000063  ]
# [ 22.49988211  14.99992045 -13.00002483]
# [-7.49987872 25.99997706 13.00015082]
# [ 0. 30.  0.]

# %%
def para_load2(num):
    #インスペクターから得た値で計算した後のパラメータを読み込む
    folder_path = pathlib.Path("view_mat")
    file_path = os.path.join(folder_path, str(num)+".csv")
    Rt = np.loadtxt(file_path, delimiter=",")
    return Rt


def F_mat(Rt1, Rt2):
    
    R1 = Rt1[0:3, 0:3]
    R2 = Rt2[0:3, 0:3]
    t1 = Rt1[0:3,3]
    t2 = Rt2[0:3,3]
    #print(R1, R2, t1, t2)
    R = np.dot(R2, np.linalg.inv(R1))
    t = t2-t1
    #T = T_mat(t)
    #F = np.dot(np.dot(np.dot(np.linalg.inv(A1.T), T), R), np.linalg.inv(A2))
    
    return R, t

# %%
Rt0 = para_load2(0)
Rt2 = para_load2(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-6e9eb9d7e697> in <module>
# ----> 1 Rt0 = para_load2(0)
#       2 Rt2 = para_load2(2)
#
# <ipython-input-22-3ee8a5d5442c> in para_load2(num)
#       3     folder_path = pathlib.Path("view_mat")
#       4     file_path = os.path.join(folder_path, str(num)+".csv")
# ----> 5     Rt = np.loadtxt(file_path, delimiter=",")
#       6     return Rt
#       7
#
# C:\Users\murata\anaconda3\envs\ana37\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1157         # converting the data
#    1158         X = None
# -> 1159         for x in read_data(_loadtxt_chunksize):
#    1160             if X is None:
#    1161                 X = np.array(x, dtype)
#
# C:\Users\murata\anaconda3\envs\ana37\lib\site-packages\numpy\lib\npyio.py in read_data(chunk_size)
#    1085
#    1086             # Convert each value according to its column and store
# -> 1087             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1088
#    1089             # Then pack it according to the dtype's nesting
#
# C:\Users\murata\anaconda3\envs\ana37\lib\site-packages\numpy\lib\npyio.py in <listcomp>(.0)
#    1085
#    1086             # Convert each value according to its column and store
# -> 1087             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1088
#    1089             # Then pack it according to the dtype's nesting
#
# C:\Users\murata\anaconda3\envs\ana37\lib\site-packages\numpy\lib\npyio.py in floatconv(x)
#     792         if '0x' in x:
#     793             return float.fromhex(x)
# --> 794         return float(x)
#     795
#     796     typ = dtype.type
#
# ValueError: could not convert string to float: '-0.86619\t0.00000\t0.49972\t0.00000'

# %%
R0to2, t0to2 = F_mat(Rt0,Rt2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-4a2249327f09> in <module>
# ----> 1 R0to2, t0to2 = F_mat(Rt0,Rt2)
#
# NameError: name 'Rt0' is not defined

# %%
print(R0to2, t0to2)
# Out:
# [[ 0.8657114  -0.40723086 -0.29104379]
#  [ 0.40723132  0.91111318 -0.06352652]
#  [ 0.2910442  -0.06352654  0.95459822]] [ 0.55  0.   -0.55]

# %%
fig = plt.figure(figsize = (10, 8))
ax = fig.add_subplot(111, projection='3d')
    # 軸ラベルの設定
ax.set_xlabel("x", fontsize = 16)
ax.set_ylabel("y", fontsize = 16)
ax.set_zlabel("z", fontsize = 16)

# 軸範囲の設定
ax.set_xlim(-3, 3)
ax.set_ylim(-3, 3)
ax.set_zlim(-3, 3)

# 格子点の作成
x = np.arange(-3, 3, 0.2)
y = np.arange(-3, 3, 0.2)
xx, yy = np.meshgrid(x, y)

R, t = para_load(0)
loc, x_vec, y_vec, z_vec = rotation(R, t)
roted_ax(loc, x_vec, y_vec, z_vec)

loc = t + t0to2
rot_mat = np.dot(R0to2, np.stack([x_vec, y_vec, z_vec]))
x_vec, y_vec, z_vec = rot_mat[0, 0:3], rot_mat[1, 0:3], rot_mat[2, 0:3]
roted_ax(loc, x_vec, y_vec, z_vec)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig = plt.figure(figsize = (10, 8))
ax = fig.add_subplot(111, projection='3d')
    # 軸ラベルの設定
ax.set_xlabel("x", fontsize = 16)
ax.set_ylabel("y", fontsize = 16)
ax.set_zlabel("z", fontsize = 16)

# 軸範囲の設定
ax.set_xlim(-3, 3)
ax.set_ylim(-3, 3)
ax.set_zlim(-3, 3)

# 格子点の作成
x = np.arange(-3, 3, 0.2)
y = np.arange(-3, 3, 0.2)
xx, yy = np.meshgrid(x, y)

R, t = para_load(0)
loc, x_vec, y_vec, z_vec = rotation(R, t)
roted_ax(loc, x_vec, y_vec, z_vec)

R, t = para_load(2)
loc, x_vec, y_vec, z_vec = rotation(R, t)
roted_ax(loc, x_vec, y_vec, z_vec)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
