# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
main_img_path = "output_images_test_2/marged_exp2021_005_GmJMC112_01_MVI_04_opt_curves_upper/reconstruction/v_13.jpg"
sub_img_path = "output_images_test_2/exp2021_005_GmJMC112_01_MVI_04_opt_curves_upper/reconstruction/v_13.jpg"

# %%
main_img = cv2.imread(main_img_path)
main_gray_img = cv2.imread(main_img_path, 0)
sub_gray_img = cv2.imread(sub_img_path, 0)
sub_img = cv2.imread(sub_img_path)

# %%
dst = cv2.addWeighted(main_img, 0.8, sub_img, 0.2, 0)

# %%
plt.imshow(dst)

# %%
cv2.imwrite("marged_exp2021_005_GmJMC112_01_MVI_04_opt_curves_upper_v_13_frag.jpg", dst)
# Out:
# True
